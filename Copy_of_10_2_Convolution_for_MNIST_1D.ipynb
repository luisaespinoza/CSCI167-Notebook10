# %% [markdown]
# <a href="https://colab.research.google.com/github/luisaespinoza/CSCI167-Notebook10/blob/main/Copy_of_10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-6vj_alt6
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-6vj_alt6
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=4cb356e0e93bb8322e9511c5ce80ba180fc5bf7d3702071a3c28294c54fb5115
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xaj44exh/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
# model = nn.Sequential(
# nn.Flatten(),
# nn.Linear(40, 100),
# nn.ReLU(),
# nn.Linear(100, 100),
# nn.ReLU(),
# nn.Linear(100, 10))
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.779478, train error 71.03,  val loss 1.796757, percent error 73.40
# Epoch     1, train loss 1.485036, train error 58.83,  val loss 1.505207, percent error 63.30
# Epoch     2, train loss 1.363875, train error 55.92,  val loss 1.354836, percent error 58.00
# Epoch     3, train loss 1.360701, train error 56.17,  val loss 1.383879, percent error 58.40
# Epoch     4, train loss 1.223411, train error 49.35,  val loss 1.244510, percent error 52.00
# Epoch     5, train loss 1.220253, train error 50.00,  val loss 1.260373, percent error 53.80
# Epoch     6, train loss 1.267190, train error 52.88,  val loss 1.294580, percent error 56.70
# Epoch     7, train loss 1.071261, train error 43.10,  val loss 1.094629, percent error 46.40
# Epoch     8, train loss 1.026916, train error 40.28,  val loss 1.063119, percent error 43.90
# Epoch     9, train loss 0.929504, train error 36.90,  val loss 0.970502, percent error 39.80
# Epoch    10, train loss 0.861226, train error 34.80,  val loss 0.896753, percent error 38.00
# Epoch    11, train loss 0.858076, train error 34.90,  val loss 0.905386, percent error 38.50
# Epoch    12, train loss 0.757475, train error 30.93,  val loss 0.827533, percent error 35.20
# Epoch    13, train loss 0.677357, train error 26.38,  val loss 0.741800, percent error 31.20
# Epoch    14, train loss 0.683040, train error 26.32,  val loss 0.757580, percent error 28.90
# Epoch    15, train loss 0.535267, train error 20.60,  val loss 0.622001, percent error 24.20
# Epoch    16, train loss 0.468699, train error 17.60,  val loss 0.567716, percent error 22.60
# Epoch    17, train loss 0.504705, train error 19.57,  val loss 0.600089, percent error 21.80
# Epoch    18, train loss 0.340539, train error 11.88,  val loss 0.452832, percent error 18.30
# Epoch    19, train loss 0.412671, train error 15.55,  val loss 0.531312, percent error 20.00
# Epoch    20, train loss 0.262426, train error 8.95,  val loss 0.392696, percent error 14.20
# Epoch    21, train loss 0.231907, train error 7.97,  val loss 0.379222, percent error 13.70
# Epoch    22, train loss 0.222823, train error 7.43,  val loss 0.378784, percent error 14.30
# Epoch    23, train loss 0.203078, train error 6.78,  val loss 0.363883, percent error 12.80
# Epoch    24, train loss 0.196474, train error 6.50,  val loss 0.352127, percent error 12.60
# Epoch    25, train loss 0.176662, train error 5.57,  val loss 0.369139, percent error 12.80
# Epoch    26, train loss 0.170317, train error 5.70,  val loss 0.363418, percent error 12.10
# Epoch    27, train loss 0.192223, train error 6.70,  val loss 0.391805, percent error 13.30
# Epoch    28, train loss 0.162144, train error 5.35,  val loss 0.376295, percent error 12.30
# Epoch    29, train loss 0.154783, train error 5.25,  val loss 0.344714, percent error 11.80
# Epoch    30, train loss 0.139836, train error 4.45,  val loss 0.365960, percent error 11.80
# Epoch    31, train loss 0.133684, train error 4.22,  val loss 0.362529, percent error 11.70
# Epoch    32, train loss 0.130220, train error 4.22,  val loss 0.383572, percent error 11.50
# Epoch    33, train loss 0.128452, train error 3.93,  val loss 0.394340, percent error 11.10
# Epoch    34, train loss 0.115561, train error 3.68,  val loss 0.359913, percent error 10.90
# Epoch    35, train loss 0.124634, train error 4.40,  val loss 0.382155, percent error 10.30
# Epoch    36, train loss 0.136999, train error 4.88,  val loss 0.392240, percent error 11.00
# Epoch    37, train loss 0.103835, train error 3.22,  val loss 0.373337, percent error 10.70
# Epoch    38, train loss 0.126082, train error 4.75,  val loss 0.400333, percent error 11.40
# Epoch    39, train loss 0.107621, train error 3.90,  val loss 0.357449, percent error 11.10
# Epoch    40, train loss 0.081954, train error 2.35,  val loss 0.358974, percent error 10.90
# Epoch    41, train loss 0.077852, train error 2.10,  val loss 0.358596, percent error 9.90
# Epoch    42, train loss 0.075465, train error 2.20,  val loss 0.367106, percent error 9.70
# Epoch    43, train loss 0.070889, train error 2.00,  val loss 0.356842, percent error 10.20
# Epoch    44, train loss 0.066460, train error 1.78,  val loss 0.356602, percent error 9.30
# Epoch    45, train loss 0.067085, train error 1.75,  val loss 0.368665, percent error 10.70
# Epoch    46, train loss 0.069134, train error 1.97,  val loss 0.376216, percent error 10.20
# Epoch    47, train loss 0.067497, train error 1.88,  val loss 0.370244, percent error 9.90
# Epoch    48, train loss 0.063252, train error 1.68,  val loss 0.373893, percent error 10.10
# Epoch    49, train loss 0.063874, train error 1.88,  val loss 0.388881, percent error 10.50
# Epoch    50, train loss 0.057707, train error 1.30,  val loss 0.375147, percent error 9.90
# Epoch    51, train loss 0.063700, train error 1.78,  val loss 0.373656, percent error 10.70
# Epoch    52, train loss 0.066162, train error 1.82,  val loss 0.404014, percent error 10.50
# Epoch    53, train loss 0.061517, train error 1.75,  val loss 0.390266, percent error 10.20
# Epoch    54, train loss 0.055664, train error 1.38,  val loss 0.385490, percent error 9.90
# Epoch    55, train loss 0.051741, train error 1.20,  val loss 0.390551, percent error 9.90
# Epoch    56, train loss 0.054191, train error 1.43,  val loss 0.400616, percent error 10.20
# Epoch    57, train loss 0.051449, train error 1.22,  val loss 0.403570, percent error 10.30
# Epoch    58, train loss 0.052068, train error 1.22,  val loss 0.392804, percent error 10.20
# Epoch    59, train loss 0.049346, train error 1.35,  val loss 0.397284, percent error 10.00
# Epoch    60, train loss 0.044420, train error 0.97,  val loss 0.400695, percent error 10.00
# Epoch    61, train loss 0.044018, train error 1.07,  val loss 0.400228, percent error 10.10
# Epoch    62, train loss 0.043650, train error 0.85,  val loss 0.400501, percent error 10.00
# Epoch    63, train loss 0.043712, train error 0.90,  val loss 0.402954, percent error 9.60
# Epoch    64, train loss 0.043073, train error 0.93,  val loss 0.407010, percent error 10.20
# Epoch    65, train loss 0.043546, train error 0.95,  val loss 0.410507, percent error 9.70
# Epoch    66, train loss 0.042220, train error 0.88,  val loss 0.414712, percent error 10.30
# Epoch    67, train loss 0.041326, train error 0.88,  val loss 0.403089, percent error 10.00
# Epoch    68, train loss 0.040020, train error 0.75,  val loss 0.408028, percent error 9.70
# Epoch    69, train loss 0.040649, train error 0.82,  val loss 0.412723, percent error 10.50
# Epoch    70, train loss 0.040960, train error 0.82,  val loss 0.419686, percent error 10.30
# Epoch    71, train loss 0.039575, train error 0.72,  val loss 0.417197, percent error 9.60
# Epoch    72, train loss 0.038465, train error 0.70,  val loss 0.419115, percent error 10.30
# Epoch    73, train loss 0.038873, train error 0.80,  val loss 0.424413, percent error 9.70
# Epoch    74, train loss 0.038298, train error 0.65,  val loss 0.422770, percent error 10.20
# Epoch    75, train loss 0.038615, train error 0.78,  val loss 0.424491, percent error 10.20
# Epoch    76, train loss 0.036965, train error 0.62,  val loss 0.419918, percent error 9.90
# Epoch    77, train loss 0.037870, train error 0.72,  val loss 0.429212, percent error 9.70
# Epoch    78, train loss 0.037916, train error 0.78,  val loss 0.425935, percent error 10.30
# Epoch    79, train loss 0.037210, train error 0.70,  val loss 0.427660, percent error 9.40
# Epoch    80, train loss 0.034952, train error 0.60,  val loss 0.427956, percent error 10.20
# Epoch    81, train loss 0.035026, train error 0.65,  val loss 0.428714, percent error 9.60
# Epoch    82, train loss 0.034843, train error 0.62,  val loss 0.426658, percent error 10.00
# Epoch    83, train loss 0.034679, train error 0.57,  val loss 0.424818, percent error 9.90
# Epoch    84, train loss 0.034355, train error 0.57,  val loss 0.430294, percent error 10.00
# Epoch    85, train loss 0.034090, train error 0.50,  val loss 0.430269, percent error 10.50
# Epoch    86, train loss 0.033895, train error 0.55,  val loss 0.428493, percent error 9.90
# Epoch    87, train loss 0.034362, train error 0.57,  val loss 0.432130, percent error 10.40
# Epoch    88, train loss 0.033731, train error 0.57,  val loss 0.434950, percent error 10.30
# Epoch    89, train loss 0.033265, train error 0.57,  val loss 0.433353, percent error 10.00
# Epoch    90, train loss 0.033482, train error 0.55,  val loss 0.438442, percent error 10.50
# Epoch    91, train loss 0.033004, train error 0.60,  val loss 0.435458, percent error 10.20
# Epoch    92, train loss 0.032984, train error 0.55,  val loss 0.440021, percent error 10.20
# Epoch    93, train loss 0.032907, train error 0.47,  val loss 0.440488, percent error 10.60
# Epoch    94, train loss 0.032400, train error 0.57,  val loss 0.437181, percent error 10.00
# Epoch    95, train loss 0.032359, train error 0.57,  val loss 0.436033, percent error 10.10
# Epoch    96, train loss 0.032223, train error 0.53,  val loss 0.440989, percent error 9.90
# Epoch    97, train loss 0.032029, train error 0.55,  val loss 0.438802, percent error 9.60
# Epoch    98, train loss 0.031906, train error 0.53,  val loss 0.440777, percent error 9.60
# Epoch    99, train loss 0.031545, train error 0.47,  val loss 0.439520, percent error 9.70
